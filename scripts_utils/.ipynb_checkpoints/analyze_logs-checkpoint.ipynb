# %%
import pandas as pd
import os

# %%
paramspace = pd.read_csv("../data/metadata/paramspace_phaseII.csv", index_col = 0)
paramspace

# %%
logs = os.listdir('../logs/count_cfDNA_kmers_filtered_cfDNA/')
#logs = os.listdir('../logs/emp_dist_analysis_make_plotfile_intersection_ci4_cs1e9/')
#logs = os.listdir('../logs/emp_dist_analysis_intersect_cfDNA_unique_tumor_all_germline_filtered_tumor_bams_ci5_cs1e9/')

for i, log_file in enumerate(logs): 
    if str(log_file.split(".")[-1]) == "ipynb_checkpoints":
        continue
    finished = False
    steps = False
    file1 = open('../logs/count_cfDNA_kmers_filtered_cfDNA/' + log_file, 'r')
    lines = file1.readlines()
    if i % 10 == 0: 
        print(i)
    
    if lines[0].strip() == "Waiting at most 60 seconds for missing files.":
        print(lines[0])
        #cmd = 'rm ../logs/emp_dist_analysis_make_plotfile_intersection_ci4_cs1e9/' + log_file
        #os.system(cmd)
        continue
    for line in lines:
        if str(line.strip()) == "Finished job 0.":
            #print(line.strip())
            finished = True
        if finished == True and str(line.strip()) == "1 of 1 steps (100%) done":
            #print(line.strip())
            steps = True
    
    if finished != True or steps != True:
        print(log_file)
        print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -")
    file1.close()

# %%
logs = os.listdir('../logs/count_cfDNA_kmers_filtered_cfDNA/')

for i, log_file in enumerate(logs): 
    if str(log_file.split(".")[-1]) == "ipynb_checkpoints":
        continue
    finished = False
    steps = False
    file1 = open('../logs/count_cfDNA_kmers_filtered_cfDNA/' + log_file, 'r')
    lines = file1.readlines()
    if i % 400 == 0: 
        print(i)
    
    if lines[0].strip() == "Waiting at most 60 seconds for missing files." or lines[0].strip() == 'Error: Snakefile "/faststorage/project/c2i-colon/WorkSpaces/CarmenAndAnika/snakefile_empricial_distribution_analysis" not found.':
        print(lines[0])
        cmd = 'rm ../logs/count_cfDNA_kmers_filtered_cfDNA/' + log_file
        os.system(cmd)
        continue
    for line in lines:
        if line.strip() == "Exiting because a job execution failed. Look above for error message":
            print(line)
            cmd = 'rm ../logs/count_cfDNA_kmers_filtered_cfDNA/' + log_file
            os.system(cmd)
            break
        if str(line.strip()) == "Finished job 0.":
            #print(line.strip())
            finished = True
        if finished == True and str(line.strip()) == "1 of 1 steps (100%) done":
            #print(line.strip())
            steps = True
    
    if finished != True or steps != True:
        print(log_file)
        print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -")
    file1.close()

# %%
logs = os.listdir('../logs/count_cfDNA_kmers_filtered_cfDNA/')

for i, log_file in enumerate(logs): 
    if str(log_file.split(".")[-1]) == "ipynb_checkpoints":
        continue
    finished = False
    steps = False
    file1 = open('../logs/count_cfDNA_kmers_filtered_cfDNA/' + log_file, 'r')
    lines = file1.readlines()
    if i % 400 == 0: 
        print(i)
    
    if lines[0].strip() == "Waiting at most 60 seconds for missing files." or lines[0].strip() == 'Error: Snakefile "/faststorage/project/c2i-colon/WorkSpaces/CarmenAndAnika/snakefile_empricial_distribution_analysis" not found.':
        print(lines[0])
        cmd = 'rm ../logs/count_cfDNA_kmers_filtered_cfDNA/' + log_file
        os.system(cmd)
        continue
    for line in lines:
        if line.strip() == "Exiting because a job execution failed. Look above for error message":
            print(line)
            cmd = 'rm ../logs/count_cfDNA_kmers_filtered_cfDNA/' + log_file
            os.system(cmd)
            break
        if str(line.strip()) == "Finished job 0.":
            #print(line.strip())
            finished = True
        if finished == True and str(line.strip()) == "1 of 1 steps (100%) done":
            #print(line.strip())
            steps = True
    
    if finished != True or steps != True:
        print(log_file)
        print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -")
    file1.close()

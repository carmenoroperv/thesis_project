# %%
import os
import pandas as pd

# %%
# input parameters

# insert here the phase (I or II) you want to create the paramspace for
target_phase = "phaseII"

# %%
clin_data = pd.read_csv("../../data/metadata/clin_data/clinical_data.csv")
clin_data.head()

mask = clin_data.C2i_phase == target_phase
clin_data_phase = clin_data[mask]
clin_data_phase.head()

samples_pts = ["C0" + str(sample) for sample in clin_data_phase.biobankID.tolist()]
samples_pts

samples_pts = ["C0" + str(sample) for sample in clin_data_phase.biobankID.tolist()]
print(samples_pts)
print(f"Number of patients in {target_phase}: {len(samples_pts)}.")
# Out:
# ['C05707', 'C06018', 'C06428']

# %%
paramspace_cfdna = pd.DataFrame({})

def check(x):
    if "ffpe" in x:
        return True
    elif "frfr" in x: 
        return True
    else:
        return False

for pt in samples_pts:
    folders = os.listdir("../../../../DerivedData/main_data/" + str(pt))
    cfDNA_samples = []
    print(folders)
    unique_kmers_folder =  [x for x in folders if check(x)]
    for folder in folders: 
        files = os.listdir("../../../../DerivedData/main_data/" + str(pt) + "/" + str(folder))
        print(files)        
        for file in files:
            file_suf = file.split(".")[-1]
            print(file_suf)
            if file_suf == "bam":     
                dna_type = file.split("_")[1].split(".")[0]
                print(dna_type)
                if dna_type == "buffycoat":
                    continue
                elif dna_type == "cfdna":
                    cfDNA_folder = folder
                    cfDNA_sample = file
                else:
                    continue
                add = {'pt_id': pt,
                       'cfDNA_folder': folder,
                       'cfDNA_file': file,
                       'cfDNA_bam_path': "../../DerivedData/main_data/" + pt + "/" + folder + "/" + file, #"data/"
                       'unique_kmers_folder': unique_kmers_folder[0]
                              }
                paramspace_cfdna = paramspace_cfdna.append(add, ignore_index = True)
        
    
paramspace_cfdna = paramspace_cfdna.sort_values(by=["pt_id"])
paramspace_cfdna = paramspace_cfdna.reset_index(drop = True)
paramspace_cfdna
# Out:
# ['C55A05707D_cfdna_N295-1106', 'C54A05707D_cfdna_N295-1101', 'C43T05707D_frfr_N295-1727']
# ['workflow', 'C55A05707D_cfdna_N295-1106_HCLYNDSX2_1.cutadapt.metrics.txt', 'C55A05707D_cfdna.insert_size_metrics.pdf', 'C55A05707D_cfdna.wgs_metrics.txt', 'C55A05707D_cfdna_N295-1106_HCLYNDSX2_2.cutadapt.metrics.txt', 'C55A05707D_cfdna_N295-1106_HCLYNDSX2_4.cutadapt.metrics.txt', 'C55A05707D_cfdna.aligned.sorted.markdup.bam', 'C55A05707D_cfdna.aligned.sorted.markdup.bam.bai', 'C55A05707D_cfdna_N295-1106_HCLYNDSX2_3.cutadapt.metrics.txt', 'C55A05707D_cfdna.insert_size_metrics.txt', 'C55A05707D_cfdna.markdup_metrics.txt']
# workflow
# txt
# pdf
# txt
# txt
# txt
# bam
# cfdna
# bai
# txt
# txt
# txt
# ['C54A05707D_cfdna.aligned.sorted.markdup.bam.bai', 'C54A05707D_cfdna.insert_size_metrics.pdf', 'C54A05707D_cfdna_N295-1101_HCLYNDSX2_1.cutadapt.metrics.txt', 'C54A05707D_cfdna_N295-1101_HCLYNDSX2_4.cutadapt.metrics.txt', 'C54A05707D_cfdna.insert_size_metrics.txt', 'C54A05707D_cfdna.markdup_metrics.txt', 'workflow', 'C54A05707D_cfdna_N295-1101_HCLYNDSX2_2.cutadapt.metrics.txt', 'C54A05707D_cfdna.aligned.sorted.markdup.bam', 'C54A05707D_cfdna.wgs_metrics.txt', 'C54A05707D_cfdna_N295-1101_HCLYNDSX2_3.cutadapt.metrics.txt']
# bai
# pdf
# txt
# txt
# txt
# txt
# workflow
# txt
# bam
# cfdna
# txt
# txt
# ['C43T05707D_frfr.somatic.variants.mutect.vcf.gz.tbi', 'C46A05707D_buffycoat.germline.variants.delly.vcf.gz.tbi', 'C43T05707D_frfr.somatic.variants.delly.vcf.gz', 'C43T05707D_frfr.somatic.variants.strelka.vcf.gz', 'C43T05707D_frfr.multiqc.report.html', 'C43T05707D_frfr.tumor.alignment.bai', 'C43T05707D_frfr.tumor.alignment.bam', 'C46A05707D_buffycoat.germline.variants.haplotypecaller.vcf.gz.tbi', 'C46A05707D_buffycoat.germline.variants.haplotypecaller.vcf.gz', 'C43T05707D_frfr.somatic.variants.manta.vcf.gz.tbi', 'C46A05707D_buffycoat.germline.variants.manta.vcf.gz', 'C43T05707D_frfr.somatic.variants.mutect.vcf.gz', 'C46A05707D_buffycoat.germline.variants.delly.vcf.gz', 'C46A05707D_buffycoat.normal.alignment.bai', 'C43T05707D_frfr.somatic.variants.delly.vcf.gz.tbi', 'C43T05707D_frfr.tumor.alignment.bam.bw', 'C43T05707D_frfr.somatic.variants.strelka.vcf.gz.tbi', 'C46A05707D_buffycoat.normal.alignment.bam.bw', 'C46A05707D_buffycoat.germline.variants.manta.vcf.gz.tbi', 'C46A05707D_buffycoat.normal.alignment.bam', 'C43T05707D_frfr.somatic.variants.manta.vcf.gz', 'C43T05707D_frfr.somatic.variants.cnvkit.tsv', 'workflow']
# tbi
# tbi
# gz
# gz
# html
# bai
# bam
# frfr
# tbi
# gz
# tbi
# gz
# gz
# gz
# bai
# tbi
# bw
# tbi
# bw
# tbi
# bam
# buffycoat
# gz
# tsv
# workflow
# ['C216A06018D_cfdna_N295-534', 'C215A06018D_cfdna_N295-513', 'C217A06018D_cfdna_N295-595', 'C223A06018D_cfdna_N295-1427', 'C222A06018D_cfdna_N295-1369', 'C219A06018D_cfdna_N295-1279', 'C151T06018D_frfr_N295-852', 'C224A06018D_cfdna_N295-1551', 'C220A06018D_cfdna_N295-1280', 'C221A06018D_cfdna_N295-1321', 'C218A06018D_cfdna_N295-1213']
# ['C216A06018D_cfdna.markdup_metrics.txt', 'C216A06018D_cfdna_N295-534_HL3YYDSXY_4.cutadapt.metrics.txt', 'C216A06018D_cfdna_N295-534_HL3YYDSXY_2.cutadapt.metrics.txt', 'C216A06018D_cfdna.aligned.sorted.markdup.bam', 'C216A06018D_cfdna_N295-534_HL3YYDSXY_3.cutadapt.metrics.txt', 'C216A06018D_cfdna.insert_size_metrics.txt', 'C216A06018D_cfdna.wgs_metrics.txt', 'C216A06018D_cfdna.aligned.sorted.markdup.bam.bai', 'workflow', 'C216A06018D_cfdna.insert_size_metrics.pdf', 'C216A06018D_cfdna_N295-534_HL3YYDSXY_1.cutadapt.metrics.txt']
# txt
# txt
# txt
# bam
# cfdna
# txt
# txt
# txt
# bai
# workflow
# pdf
# txt
# ['C215A06018D_cfdna.aligned.sorted.markdup.bam', 'C215A06018D_cfdna_N295-513_HYJ7FDSXY_3.cutadapt.metrics.txt', 'workflow', 'C215A06018D_cfdna_N295-513_HYJ7FDSXY_4.cutadapt.metrics.txt', 'C215A06018D_cfdna_N295-513_HYJ7FDSXY_2.cutadapt.metrics.txt', 'C215A06018D_cfdna.insert_size_metrics.pdf', 'C215A06018D_cfdna.aligned.sorted.markdup.bam.bai', 'C215A06018D_cfdna_N295-513_HYJ7FDSXY_1.cutadapt.metrics.txt', 'C215A06018D_cfdna.wgs_metrics.txt', 'C215A06018D_cfdna.insert_size_metrics.txt', 'C215A06018D_cfdna.markdup_metrics.txt']
# bam
# cfdna
# txt
# workflow
# txt
# txt
# pdf
# bai
# txt
# txt
# txt
# txt
# ['C217A06018D_cfdna.wgs_metrics.txt', 'C217A06018D_cfdna_N295-595_H37MFDSX2_3.cutadapt.metrics.txt', 'C217A06018D_cfdna_N295-595_H37MFDSX2_2.cutadapt.metrics.txt', 'C217A06018D_cfdna.aligned.sorted.markdup.bam.bai', 'C217A06018D_cfdna_N295-595_H37MFDSX2_4.cutadapt.metrics.txt', 'C217A06018D_cfdna.insert_size_metrics.pdf', 'C217A06018D_cfdna_N295-595_H37MFDSX2_1.cutadapt.metrics.txt', 'C217A06018D_cfdna.aligned.sorted.markdup.bam', 'workflow', 'C217A06018D_cfdna.markdup_metrics.txt', 'C217A06018D_cfdna.insert_size_metrics.txt']
# txt
# txt
# txt
# bai
# txt
# pdf
# txt
# bam
# cfdna
# workflow
# txt
# txt
# ['C223A06018D_cfdna_N295-1427_HFJGNDSX2_3.cutadapt.metrics.txt', 'C223A06018D_cfdna.aligned.sorted.markdup.bam.bai', 'workflow', 'C223A06018D_cfdna.insert_size_metrics.txt', 'C223A06018D_cfdna.wgs_metrics.txt', 'C223A06018D_cfdna_N295-1427_HFJGNDSX2_2.cutadapt.metrics.txt', 'C223A06018D_cfdna.aligned.sorted.markdup.bam', 'C223A06018D_cfdna.markdup_metrics.txt', 'C223A06018D_cfdna_N295-1427_HFJGNDSX2_4.cutadapt.metrics.txt', 'C223A06018D_cfdna_N295-1427_HFJGNDSX2_1.cutadapt.metrics.txt', 'C223A06018D_cfdna.insert_size_metrics.pdf']
# txt
# bai
# workflow
# txt
# txt
# txt
# bam
# cfdna
# txt
# txt
# txt
# pdf
# ['C222A06018D_cfdna.wgs_metrics.txt', 'C222A06018D_cfdna.markdup_metrics.txt', 'C222A06018D_cfdna_N295-1369_HGMNWDSX2_1.cutadapt.metrics.txt', 'C222A06018D_cfdna.insert_size_metrics.txt', 'workflow', 'C222A06018D_cfdna_N295-1369_HGMNWDSX2_3.cutadapt.metrics.txt', 'C222A06018D_cfdna.aligned.sorted.markdup.bam', 'C222A06018D_cfdna.insert_size_metrics.pdf', 'C222A06018D_cfdna_N295-1369_HGMNWDSX2_4.cutadapt.metrics.txt', 'C222A06018D_cfdna.aligned.sorted.markdup.bam.bai', 'C222A06018D_cfdna_N295-1369_HGMNWDSX2_2.cutadapt.metrics.txt']
# txt
# txt
# txt
# txt
# workflow
# txt
# bam
# cfdna
# pdf
# txt
# bai
# txt
# ['C219A06018D_cfdna.insert_size_metrics.txt', 'C219A06018D_cfdna.wgs_metrics.txt', 'C219A06018D_cfdna.aligned.sorted.markdup.bam', 'workflow', 'C219A06018D_cfdna_N295-1279_HGLWYDSX2_3.cutadapt.metrics.txt', 'C219A06018D_cfdna.markdup_metrics.txt', 'C219A06018D_cfdna_N295-1279_HGLWYDSX2_4.cutadapt.metrics.txt', 'C219A06018D_cfdna_N295-1279_H2GHCDSX3_2.cutadapt.metrics.txt', 'C219A06018D_cfdna_N295-1279_HGLWYDSX2_2.cutadapt.metrics.txt', 'C219A06018D_cfdna.insert_size_metrics.pdf', 'C219A06018D_cfdna_N295-1279_HGLWYDSX2_1.cutadapt.metrics.txt', 'C219A06018D_cfdna.aligned.sorted.markdup.bam.bai', 'C219A06018D_cfdna_N295-1279_H2GHCDSX3_1.cutadapt.metrics.txt']
# txt
# txt
# bam
# cfdna
# workflow
# txt
# txt
# txt
# txt
# txt
# pdf
# txt
# bai
# txt
# ['C151T06018D_frfr.somatic.variants.mutect.vcf.gz', 'C137A06018D_buffycoat.germline.variants.haplotypecaller.vcf.gz', 'C137A06018D_buffycoat.normal.alignment.bam', 'C137A06018D_buffycoat.germline.variants.manta.vcf.gz.tbi', 'C151T06018D_frfr.somatic.variants.mutect.vcf.gz.tbi', 'C151T06018D_frfr.somatic.variants.delly.vcf.gz', 'C151T06018D_frfr.somatic.variants.cnvkit.tsv', 'C151T06018D_frfr.tumor.alignment.bam', 'C151T06018D_frfr.tumor.alignment.bai', 'C137A06018D_buffycoat.germline.variants.manta.vcf.gz', 'C137A06018D_buffycoat.germline.variants.haplotypecaller.vcf.gz.tbi', 'C151T06018D_frfr.multiqc.report.html', 'C151T06018D_frfr.somatic.variants.manta.vcf.gz.tbi', 'C137A06018D_buffycoat.normal.alignment.bai', 'C137A06018D_buffycoat.germline.variants.delly.vcf.gz', 'C151T06018D_frfr.somatic.variants.strelka.vcf.gz', 'C151T06018D_frfr.tumor.alignment.bam.bw', 'C151T06018D_frfr.somatic.variants.delly.vcf.gz.tbi', 'C137A06018D_buffycoat.normal.alignment.bam.bw', 'workflow', 'C151T06018D_frfr.somatic.variants.strelka.vcf.gz.tbi', 'C137A06018D_buffycoat.germline.variants.delly.vcf.gz.tbi', 'C151T06018D_frfr.somatic.variants.manta.vcf.gz']
# gz
# gz
# bam
# buffycoat
# tbi
# tbi
# gz
# tsv
# bam
# frfr
# bai
# gz
# tbi
# html
# tbi
# bai
# gz
# gz
# bw
# tbi
# bw
# workflow
# tbi
# tbi
# gz
# ['C224A06018D_cfdna_N295-1551_HJJY2DSX2_4.cutadapt.metrics.txt', 'C224A06018D_cfdna_N295-1551_HJJY2DSX2_2.cutadapt.metrics.txt', 'C224A06018D_cfdna.insert_size_metrics.txt', 'workflow', 'C224A06018D_cfdna_N295-1551_HJJY2DSX2_3.cutadapt.metrics.txt', 'C224A06018D_cfdna.markdup_metrics.txt', 'C224A06018D_cfdna.aligned.sorted.markdup.bam', 'C224A06018D_cfdna.wgs_metrics.txt', 'C224A06018D_cfdna.aligned.sorted.markdup.bam.bai', 'C224A06018D_cfdna.insert_size_metrics.pdf', 'C224A06018D_cfdna_N295-1551_HJJY2DSX2_1.cutadapt.metrics.txt']
# txt
# txt
# txt
# workflow
# txt
# txt
# bam
# cfdna
# txt
# bai
# pdf
# txt
# ['C220A06018D_cfdna.aligned.sorted.markdup.bam', 'C220A06018D_cfdna_N295-1280_HGLWYDSX2_3.cutadapt.metrics.txt', 'C220A06018D_cfdna.insert_size_metrics.txt', 'C220A06018D_cfdna_N295-1280_HGLWYDSX2_4.cutadapt.metrics.txt', 'C220A06018D_cfdna_N295-1280_HGLWYDSX2_2.cutadapt.metrics.txt', 'C220A06018D_cfdna.wgs_metrics.txt', 'C220A06018D_cfdna_N295-1280_HGLWYDSX2_1.cutadapt.metrics.txt', 'C220A06018D_cfdna.insert_size_metrics.pdf', 'C220A06018D_cfdna.aligned.sorted.markdup.bam.bai', 'workflow', 'C220A06018D_cfdna.markdup_metrics.txt']
# bam
# cfdna
# txt
# txt
# txt
# txt
# txt
# txt
# pdf
# bai
# workflow
# txt
# ['C221A06018D_cfdna.aligned.sorted.markdup.bam', 'C221A06018D_cfdna.wgs_metrics.txt', 'C221A06018D_cfdna_N295-1321_HCMFTDSX2_4.cutadapt.metrics.txt', 'C221A06018D_cfdna.markdup_metrics.txt', 'C221A06018D_cfdna_N295-1321_HCMFTDSX2_2.cutadapt.metrics.txt', 'C221A06018D_cfdna.insert_size_metrics.pdf', 'C221A06018D_cfdna.aligned.sorted.markdup.bam.bai', 'C221A06018D_cfdna_N295-1321_HCMFTDSX2_3.cutadapt.metrics.txt', 'workflow', 'C221A06018D_cfdna.insert_size_metrics.txt', 'C221A06018D_cfdna_N295-1321_HCMFTDSX2_1.cutadapt.metrics.txt']
# bam
# cfdna
# txt
# txt
# txt
# txt
# pdf
# bai
# txt
# workflow
# txt
# txt
# ['C218A06018D_cfdna.insert_size_metrics.pdf', 'C218A06018D_cfdna_N295-1213_HFJ7VDSX2_4.cutadapt.metrics.txt', 'C218A06018D_cfdna_N295-1213_HFJ7VDSX2_2.cutadapt.metrics.txt', 'C218A06018D_cfdna.wgs_metrics.txt', 'C218A06018D_cfdna_N295-1213_HFJ7VDSX2_3.cutadapt.metrics.txt', 'C218A06018D_cfdna.aligned.sorted.markdup.bam', 'C218A06018D_cfdna.insert_size_metrics.txt', 'C218A06018D_cfdna.aligned.sorted.markdup.bam.bai', 'C218A06018D_cfdna.markdup_metrics.txt', 'workflow', 'C218A06018D_cfdna_N295-1213_HFJ7VDSX2_1.cutadapt.metrics.txt']
# pdf
# txt
# txt
# txt
# txt
# bam
# cfdna
# txt
# bai
# txt
# workflow
# txt
# ['C123A06428D_cfdna_N295-1567', 'C38T06428D_ffpe_N295-927', 'C120A06428D_cfdna_N295-1460', 'C124A06428D_cfdna_N295-1597', 'C121A06428D_cfdna_N295-1471', 'C122A06428D_cfdna_N295-1524']
# ['C123A06428D_cfdna_N295-1567_HJL3GDSX2_2.cutadapt.metrics.txt', 'C123A06428D_cfdna.aligned.sorted.markdup.bam.bai', 'C123A06428D_cfdna_N295-1567_HJL3GDSX2_4.cutadapt.metrics.txt', 'C123A06428D_cfdna.insert_size_metrics.pdf', 'C123A06428D_cfdna.wgs_metrics.txt', 'C123A06428D_cfdna_N295-1567_HJL3GDSX2_3.cutadapt.metrics.txt', 'C123A06428D_cfdna.markdup_metrics.txt', 'workflow', 'C123A06428D_cfdna.insert_size_metrics.txt', 'C123A06428D_cfdna_N295-1567_HJL3GDSX2_1.cutadapt.metrics.txt', 'C123A06428D_cfdna.aligned.sorted.markdup.bam']
# txt
# bai
# txt
# pdf
# txt
# txt
# txt
# workflow
# txt
# txt
# bam
# cfdna
# ['C22A06428D_buffycoat.germline.variants.haplotypecaller.vcf.gz.tbi', 'C22A06428D_buffycoat.normal.alignment.bam', 'C22A06428D_buffycoat.germline.variants.delly.vcf.gz.tbi', 'C22A06428D_buffycoat.germline.variants.delly.vcf.gz', 'C38T06428D_ffpe.tumor.alignment.bam', 'C38T06428D_ffpe.somatic.variants.mutect.vcf.gz.tbi', 'workflow', 'C38T06428D_ffpe.somatic.variants.delly.vcf.gz.tbi', 'C38T06428D_ffpe.tumor.alignment.bai', 'C38T06428D_ffpe.multiqc.report.html', 'C38T06428D_ffpe.somatic.variants.manta.vcf.gz', 'C22A06428D_buffycoat.normal.alignment.bai', 'C22A06428D_buffycoat.normal.alignment.bam.bw', 'C38T06428D_ffpe.tumor.alignment.bam.bw', 'C38T06428D_ffpe.somatic.variants.strelka.vcf.gz.tbi', 'C38T06428D_ffpe.somatic.variants.cnvkit.tsv', 'C38T06428D_ffpe.somatic.variants.manta.vcf.gz.tbi', 'C38T06428D_ffpe.somatic.variants.strelka.vcf.gz', 'C38T06428D_ffpe.somatic.variants.delly.vcf.gz', 'C38T06428D_ffpe.somatic.variants.mutect.vcf.gz', 'C22A06428D_buffycoat.germline.variants.manta.vcf.gz.tbi', 'C22A06428D_buffycoat.germline.variants.manta.vcf.gz', 'C22A06428D_buffycoat.germline.variants.haplotypecaller.vcf.gz']
# tbi
# bam
# buffycoat
# tbi
# gz
# bam
# ffpe
# tbi
# workflow
# tbi
# bai
# html
# gz
# bai
# bw
# bw
# tbi
# tsv
# tbi
# gz
# gz
# gz
# tbi
# gz
# gz
# ['C120A06428D_cfdna_N295-1460_HHHFKDSX2_3.cutadapt.metrics.txt', 'C120A06428D_cfdna.insert_size_metrics.pdf', 'C120A06428D_cfdna_N295-1460_HHHFKDSX2_4.cutadapt.metrics.txt', 'C120A06428D_cfdna_N295-1460_HHHFKDSX2_2.cutadapt.metrics.txt', 'C120A06428D_cfdna.aligned.sorted.markdup.bam', 'C120A06428D_cfdna.insert_size_metrics.txt', 'workflow', 'C120A06428D_cfdna.wgs_metrics.txt', 'C120A06428D_cfdna.markdup_metrics.txt', 'C120A06428D_cfdna.aligned.sorted.markdup.bam.bai', 'C120A06428D_cfdna_N295-1460_HHHFKDSX2_1.cutadapt.metrics.txt']
# txt
# pdf
# txt
# txt
# bam
# cfdna
# txt
# workflow
# txt
# txt
# bai
# txt
# ['C124A06428D_cfdna.insert_size_metrics.txt', 'C124A06428D_cfdna_N295-1597_HJLCCDSX2_1.cutadapt.metrics.txt', 'C124A06428D_cfdna.aligned.sorted.markdup.bam.bai', 'C124A06428D_cfdna.wgs_metrics.txt', 'C124A06428D_cfdna.markdup_metrics.txt', 'C124A06428D_cfdna.insert_size_metrics.pdf', 'C124A06428D_cfdna_N295-1597_HJLCCDSX2_3.cutadapt.metrics.txt', 'workflow', 'C124A06428D_cfdna_N295-1597_HJLCCDSX2_4.cutadapt.metrics.txt', 'C124A06428D_cfdna_N295-1597_HJLCCDSX2_2.cutadapt.metrics.txt', 'C124A06428D_cfdna.aligned.sorted.markdup.bam']
# txt
# txt
# bai
# txt
# txt
# pdf
# txt
# workflow
# txt
# txt
# bam
# cfdna
# ['C121A06428D_cfdna_N295-1471_HHHFKDSX2_1.cutadapt.metrics.txt', 'C121A06428D_cfdna.insert_size_metrics.pdf', 'C121A06428D_cfdna.markdup_metrics.txt', 'C121A06428D_cfdna.aligned.sorted.markdup.bam', 'C121A06428D_cfdna_N295-1471_HHHFKDSX2_3.cutadapt.metrics.txt', 'C121A06428D_cfdna.insert_size_metrics.txt', 'workflow', 'C121A06428D_cfdna_N295-1471_HHHFKDSX2_2.cutadapt.metrics.txt', 'C121A06428D_cfdna.wgs_metrics.txt', 'C121A06428D_cfdna.aligned.sorted.markdup.bam.bai', 'C121A06428D_cfdna_N295-1471_HHHFKDSX2_4.cutadapt.metrics.txt']
# txt
# pdf
# txt
# bam
# cfdna
# txt
# txt
# workflow
# txt
# txt
# bai
# txt
# ['C122A06428D_cfdna.aligned.sorted.markdup.bam', 'C122A06428D_cfdna.insert_size_metrics.pdf', 'workflow', 'C122A06428D_cfdna_N295-1524_HHGJLDSX2_1.cutadapt.metrics.txt', 'C122A06428D_cfdna.markdup_metrics.txt', 'C122A06428D_cfdna_N295-1524_HHGJLDSX2_4.cutadapt.metrics.txt', 'C122A06428D_cfdna.aligned.sorted.markdup.bam.bai', 'C122A06428D_cfdna_N295-1524_HHGJLDSX2_2.cutadapt.metrics.txt', 'C122A06428D_cfdna.insert_size_metrics.txt', 'C122A06428D_cfdna.wgs_metrics.txt', 'C122A06428D_cfdna_N295-1524_HHGJLDSX2_3.cutadapt.metrics.txt']
# bam
# cfdna
# pdf
# workflow
# txt
# txt
# txt
# bai
# txt
# txt
# txt
# txt
#      pt_id                 cfDNA_folder  \
# 0   C05707   C55A05707D_cfdna_N295-1106
# 1   C05707   C54A05707D_cfdna_N295-1101
# 2   C06018  C218A06018D_cfdna_N295-1213
# 3   C06018  C221A06018D_cfdna_N295-1321
# 4   C06018  C220A06018D_cfdna_N295-1280
# 5   C06018  C219A06018D_cfdna_N295-1279
# 6   C06018  C224A06018D_cfdna_N295-1551
# 7   C06018  C223A06018D_cfdna_N295-1427
# 8   C06018   C217A06018D_cfdna_N295-595
# 9   C06018   C215A06018D_cfdna_N295-513
# 10  C06018   C216A06018D_cfdna_N295-534
# 11  C06018  C222A06018D_cfdna_N295-1369
# 12  C06428  C121A06428D_cfdna_N295-1471
# 13  C06428  C123A06428D_cfdna_N295-1567
# 14  C06428  C120A06428D_cfdna_N295-1460
# 15  C06428  C124A06428D_cfdna_N295-1597
# 16  C06428  C122A06428D_cfdna_N295-1524
#
#                                       cfDNA_file  \
# 0    C55A05707D_cfdna.aligned.sorted.markdup.bam
# 1    C54A05707D_cfdna.aligned.sorted.markdup.bam
# 2   C218A06018D_cfdna.aligned.sorted.markdup.bam
# 3   C221A06018D_cfdna.aligned.sorted.markdup.bam
# 4   C220A06018D_cfdna.aligned.sorted.markdup.bam
# 5   C219A06018D_cfdna.aligned.sorted.markdup.bam
# 6   C224A06018D_cfdna.aligned.sorted.markdup.bam
# 7   C223A06018D_cfdna.aligned.sorted.markdup.bam
# 8   C217A06018D_cfdna.aligned.sorted.markdup.bam
# 9   C215A06018D_cfdna.aligned.sorted.markdup.bam
# 10  C216A06018D_cfdna.aligned.sorted.markdup.bam
# 11  C222A06018D_cfdna.aligned.sorted.markdup.bam
# 12  C121A06428D_cfdna.aligned.sorted.markdup.bam
# 13  C123A06428D_cfdna.aligned.sorted.markdup.bam
# 14  C120A06428D_cfdna.aligned.sorted.markdup.bam
# 15  C124A06428D_cfdna.aligned.sorted.markdup.bam
# 16  C122A06428D_cfdna.aligned.sorted.markdup.bam
#
#                                        cfDNA_bam_path  \
# 0   data/C05707/C55A05707D_cfdna_N295-1106/C55A057...
# 1   data/C05707/C54A05707D_cfdna_N295-1101/C54A057...
# 2   data/C06018/C218A06018D_cfdna_N295-1213/C218A0...
# 3   data/C06018/C221A06018D_cfdna_N295-1321/C221A0...
# 4   data/C06018/C220A06018D_cfdna_N295-1280/C220A0...
# 5   data/C06018/C219A06018D_cfdna_N295-1279/C219A0...
# 6   data/C06018/C224A06018D_cfdna_N295-1551/C224A0...
# 7   data/C06018/C223A06018D_cfdna_N295-1427/C223A0...
# 8   data/C06018/C217A06018D_cfdna_N295-595/C217A06...
# 9   data/C06018/C215A06018D_cfdna_N295-513/C215A06...
# 10  data/C06018/C216A06018D_cfdna_N295-534/C216A06...
# 11  data/C06018/C222A06018D_cfdna_N295-1369/C222A0...
# 12  data/C06428/C121A06428D_cfdna_N295-1471/C121A0...
# 13  data/C06428/C123A06428D_cfdna_N295-1567/C123A0...
# 14  data/C06428/C120A06428D_cfdna_N295-1460/C120A0...
# 15  data/C06428/C124A06428D_cfdna_N295-1597/C124A0...
# 16  data/C06428/C122A06428D_cfdna_N295-1524/C122A0...
#
#           unique_kmers_folder
# 0   C43T05707D_frfr_N295-1727
# 1   C43T05707D_frfr_N295-1727
# 2   C151T06018D_frfr_N295-852
# 3   C151T06018D_frfr_N295-852
# 4   C151T06018D_frfr_N295-852
# 5   C151T06018D_frfr_N295-852
# 6   C151T06018D_frfr_N295-852
# 7   C151T06018D_frfr_N295-852
# 8   C151T06018D_frfr_N295-852
# 9   C151T06018D_frfr_N295-852
# 10  C151T06018D_frfr_N295-852
# 11  C151T06018D_frfr_N295-852
# 12   C38T06428D_ffpe_N295-927
# 13   C38T06428D_ffpe_N295-927
# 14   C38T06428D_ffpe_N295-927
# 15   C38T06428D_ffpe_N295-927
# 16   C38T06428D_ffpe_N295-927

# %%
paramspace_cfdna.to_csv(f"../../data/metadata/paramspace_cfDNA_{target_phase}.csv", index=False)

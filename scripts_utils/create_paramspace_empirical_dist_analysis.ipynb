# %%
import os
import pandas as pd

# %%
clin_data = pd.read_csv("../data/metadata/clin_data/clinical_data_formatted.csv")
clin_data.head()

mask = clin_data.C2i_phase == "phaseI"
clin_data_phase1 = clin_data[mask]
clin_data_phase1.head()

samples_pts = [str(sample) for sample in clin_data_phase1.patient_id.tolist()]
samples_pts
# Out:
# ['C04689',
#  'C04849',
#  'C04837',
#  'C05048',
#  'C05084',
#  'C05234',
#  'C04873',
#  'C04886',
#  'C04887',
#  'C05194',
#  'C05073',
#  'C05703',
#  'C05118',
#  'C04816',
#  'C04874']

# %%
paramspace = pd.DataFrame({})

def check(x):
    if "ffpe" in x:
        return True
    elif "frfr" in x: 
        return True
    else:
        return False

for pt in samples_pts:
    folders = os.listdir("../../../DerivedData/main_data/" + str(pt))
    unique_kmers_folder =  [x for x in folders if check(x)]
    unique_kmers_folder = unique_kmers_folder[0]
    
    other_patients = [x for x in samples_pts if x != pt]
    
    for other_pt in other_patients: 
        folders_other = os.listdir("../../../DerivedData/main_data/" + str(other_pt))
        
        unique_kmers_folder_other_pt =  [x for x in folders_other if check(x)][0]
        cfDNA_folders = [x for x in folders_other if x != unique_kmers_folder_other_pt]
        
        for cfDNA_folder in cfDNA_folders: 
            add = {
                    "patient_id": pt, 
                    "unique_tumor_kmers_folder": unique_kmers_folder,
                    "other_patient_id": other_pt, 
                    "other_patient_cfDNA_folder": cfDNA_folder
                  }
            paramspace = paramspace.append(add, ignore_index = True)

# %%
paramspace
# Out:
#      patient_id  unique_tumor_kmers_folder other_patient_id  \
# 0        C04689  C123T04689D_frfr_N295-450           C04849
# 1        C04689  C123T04689D_frfr_N295-450           C04849
# 2        C04689  C123T04689D_frfr_N295-450           C04849
# 3        C04689  C123T04689D_frfr_N295-450           C04849
# 4        C04689  C123T04689D_frfr_N295-450           C04849
# ...         ...                        ...              ...
# 2655     C04874   C82T04874D_frfr_N295-455           C04816
# 2656     C04874   C82T04874D_frfr_N295-455           C04816
# 2657     C04874   C82T04874D_frfr_N295-455           C04816
# 2658     C04874   C82T04874D_frfr_N295-455           C04816
# 2659     C04874   C82T04874D_frfr_N295-455           C04816
#
#       other_patient_cfDNA_folder
# 0     C258A04849D_cfdna_N295-141
# 1      C255A04849D_cfdna_N295-87
# 2     C194A04849D_cfdna_N295-218
# 3      C252A04849D_cfdna_N295-64
# 4     C256A04849D_cfdna_N295-115
# ...                          ...
# 2655  C282A04816D_cfdna_N295-189
# 2656  C280A04816D_cfdna_N295-161
# 2657  C278A04816D_cfdna_N295-144
# 2658   C274A04816D_cfdna_N295-92
# 2659  C272A04816D_cfdna_N295-106
#
# [2660 rows x 4 columns]

# %%
paramspace.to_csv("../data/metadata/paramspace_empirical_dist_analysis_phaseI.csv")
